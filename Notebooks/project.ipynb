# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # 1. Problem:
#
# “How can I optimize my listing to attract more bookings and maximize revenue?”
#
# # Causes for Analysis:
#
# Understand pricing trends to remain competitive.
#
# Identify high-demand neighborhoods.
#
# See how availability and minimum nights affect reviews and bookings.
#
# Learn from top-performing listings (e.g., review patterns, room types).
#
# # 2. Problem:
#
# Which listings are violating platform rules, underperforming, or affecting customer satisfaction?”
#
# # Causes for Analysis:
#
# Detect unlicensed listings or non-compliant hosts.
#
# Monitor market saturation by location or host.
#
# Identify potentially fraudulent listings (e.g., 0 reviews, high prices, long minimum stays).

# %%
url = r"C:\Users\USER\Desktop\Cube\Data_Science\Project\listings\Data\Raw"
os.chdir(url)

listing = pd.read_csv("listings.csv")
listing.head(30)
# Out:
#        id                                               name  host_id  \
# 0    2595                    Skylit Midtown Castle Sanctuary     2845
# 1    6848                   Only 2 stops to Manhattan studio    15991
# 2    6872  Uptown Sanctuary w/ Private Bath (Month to Month)    16104
# 3    6990                            UES Beautiful Blue Room    16800
# 4    7064  Amazing location! Wburg. Large, bright & tranquil    17297
# 5    7097      Perfect for Your Parents, With Garden & Patio    17571
# 6    7801                 Sunny Williamsburg Loft with Sauna    21207
# 7    8490   Maison des Sirenes1,bohemian, luminous apartment    25183
# 8    9357                               Midtown Pied-a-terre    30193
# 9   10452                      Radiant Oasis  B&B Style room    35935
# 10  11943                          Country space in the city    45445
# 11  12192                                ENJOY Downtown NYC!    46978
# 12  12940                 Charming Brownstone 3 - Near PRATT    50148
# 13  14314                     Greenpoint Place...Has It All!    56246
# 14  15341  * Lovely Nolita 1Bdrm w Elevator and 24hr Door...    60049
# 15  15385                              Very, very cozy place    60252
# 16  15396                 Sunny & Spacious Chelsea Apartment    60278
# 17  16580    Sunny, Modern room in East Village w City Views    64442
# 18  16821     Charming Room in Amazing East Village Apt. (B)     4396
# 19  16974                    SpaHa Loft: Enormous and Bright    65837
# 20  17037                            Lovely EV Artist's Home    66035
# 21  18152                                     Manhattan Room    69942
# 22  18728                Beautiful Meatpacking District Loft    71876
# 23  18961                     Cozy Studio in Great Location!    70857
# 24  19174    One bedroom Duplex Private Terrace West Village    73164
# 25  19282                    Sunny, Spacious Top Floor Haven    73469
# 26  19812        2 bedroom Williamsburg Apt - Bedford L stop    74857
# 27  20913                 Charming 1 bed GR8 WBurg LOCATION!    79402
# 28  21644                          Upper Manhattan, New York    82685
# 29  21794                COZY QUIET monthly room 4 DOOGLERS!    83257
#
#          host_name neighbourhood_group       neighbourhood   latitude  \
# 0         Jennifer           Manhattan             Midtown  40.753560
# 1    Allen & Irina            Brooklyn        Williamsburg  40.709350
# 2        Kahshanna           Manhattan         East Harlem  40.801070
# 3              Cyn           Manhattan         East Harlem  40.787780
# 4           Joelle            Brooklyn        Williamsburg  40.712480
# 5             Jane            Brooklyn         Fort Greene  40.691940
# 6            Chaya            Brooklyn        Williamsburg  40.718807
# 7         Nathalie            Brooklyn  Bedford-Stuyvesant  40.684556
# 8   Tommi Laurelle           Manhattan      Hell's Kitchen  40.767240
# 9           Angela            Brooklyn  Bedford-Stuyvesant  40.682940
# 10         Harriet            Brooklyn            Flatbush  40.637020
# 11          Edward           Manhattan        East Village  40.722960
# 12        Adreinne            Brooklyn  Bedford-Stuyvesant  40.679460
# 13          Jeanne            Brooklyn          Greenpoint  40.735350
# 14             Ted           Manhattan     Lower East Side  40.721359
# 15         Maria C            Brooklyn        Williamsburg  40.712110
# 16           Petra           Manhattan             Chelsea  40.744930
# 17            Reka           Manhattan        East Village  40.723727
# 18           Casey           Manhattan        East Village  40.722810
# 19           Robin           Manhattan         East Harlem  40.801900
# 20            Anna           Manhattan        East Village  40.722890
# 21        Victoria           Manhattan     Upper East Side  40.769670
# 22  DAVID And RICK           Manhattan             Chelsea  40.742610
# 23          Fabian           Manhattan            Kips Bay  40.738080
# 24          Alexis           Manhattan        West Village  40.739170
# 25          Djassi            Brooklyn            Flatbush  40.654370
# 26         Starlee            Brooklyn        Williamsburg  40.718020
# 27      Christiana            Brooklyn        Williamsburg  40.709670
# 28         Elliott           Manhattan              Harlem  40.827820
# 29            Olan           Manhattan             Chelsea  40.741870
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.985590  Entire home/apt    NaN              30                 49
# 1  -73.953420  Entire home/apt   96.0              30                194
# 2  -73.942550     Private room   59.0              30                  1
# 3  -73.947590     Private room   67.0              30                251
# 4  -73.958810     Private room    NaN              30                 13
# 5  -73.973890     Private room  195.0               2                398
# 6  -73.956177  Entire home/apt  290.0              30                 13
# 7  -73.939634  Entire home/apt  216.0              30                190
# 8  -73.986640  Entire home/apt  175.0              30                 58
# 9  -73.956820     Private room   90.0              30                 81
# 10 -73.963270     Private room    NaN              30                  0
# 11 -73.983830     Private room    NaN              30                317
# 12 -73.954170  Entire home/apt  110.0              30                 80
# 13 -73.955840  Entire home/apt  115.0              30                179
# 14 -73.993668  Entire home/apt  169.0              30                 40
# 15 -73.963970     Private room   97.0              30                 60
# 16 -73.995210  Entire home/apt    NaN             180                  5
# 17 -73.976259     Private room  109.0               1                620
# 18 -73.985010     Private room  136.0               1                244
# 19 -73.937620  Entire home/apt  300.0              30                291
# 20 -73.980280  Entire home/apt  230.0              30                 54
# 21 -73.948310     Private room   70.0              30                147
# 22 -74.003530     Private room  150.0              30                250
# 23 -73.980010     Private room    NaN              30                  1
# 24 -74.002070  Entire home/apt  200.0              90                 68
# 25 -73.962780     Private room   94.0              30                 16
# 26 -73.957240  Entire home/apt    NaN              30                 59
# 27 -73.959220  Entire home/apt    NaN              30                165
# 28 -73.947300     Private room    NaN              30                  3
# 29 -74.002230     Private room   85.0              30                 36
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# 0   2022-06-21               0.26                               3
# 1   2024-10-05               1.01                               1
# 2   2022-06-05               0.03                               2
# 3   2024-12-01               1.34                               1
# 4   2022-09-12               0.07                               2
# 5   2025-02-28               2.16                               2
# 6   2024-07-31               0.07                               1
# 7   2023-10-16               1.01                               2
# 8   2017-08-13               0.31                               1
# 9   2024-08-19               0.45                               6
# 10         NaN                NaN                               1
# 11  2025-01-01               1.70                               2
# 12  2025-01-06               0.43                               1
# 13  2024-09-30               0.97                               1
# 14  2024-12-02               0.29                               1
# 15  2025-01-31               0.33                               1
# 16  2018-11-03               0.05                               1
# 17  2025-02-15               4.42                               2
# 18  2025-01-30               1.60                               2
# 19  2023-09-05               1.58                               1
# 20  2024-06-06               0.30                               1
# 21  2019-09-01               0.90                               1
# 22  2024-11-15               1.47                               1
# 23  2016-03-22               0.01                               1
# 24  2024-12-27               0.38                               1
# 25  2019-07-20               0.09                               1
# 26  2018-07-29               0.32                               1
# 27  2018-07-22               0.94                               1
# 28  2019-10-21               0.04                               1
# 29  2020-01-19               0.20                               2
#
#     availability_365  number_of_reviews_ltm             license
# 0                365                      0                 NaN
# 1                173                      3                 NaN
# 2                 83                      0                 NaN
# 3                264                      5                 NaN
# 4                  0                      0                 NaN
# 5                190                     36  OSE-STRREG-0000008
# 6                  0                      1                 NaN
# 7                150                      0                 NaN
# 8                  0                      0                 NaN
# 9                137                      1                 NaN
# 10                 0                      0                 NaN
# 11                30                      1                 NaN
# 12               110                      5                 NaN
# 13               303                      2                 NaN
# 14                90                      3                 NaN
# 15               206                      3                 NaN
# 16               129                      0                 NaN
# 17               118                     68  OSE-STRREG-0000108
# 18                50                     56  OSE-STRREG-0001710
# 19                57                      0                 NaN
# 20               177                      1                 NaN
# 21               354                      0                 NaN
# 22               263                      4                 NaN
# 23                 0                      0                 NaN
# 24               300                      1                 NaN
# 25                88                      0                 NaN
# 26               227                      0                 NaN
# 27                 0                      0                 NaN
# 28                 0                      0                 NaN
# 29               364                      0                 NaN

# %%
listing.shape
# Out:
# (37434, 18)

# %%
listing.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37434 entries, 0 to 37433
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              37434 non-null  int64
#  1   name                            37432 non-null  object
#  2   host_id                         37434 non-null  int64
#  3   host_name                       37396 non-null  object
#  4   neighbourhood_group             37434 non-null  object
#  5   neighbourhood                   37434 non-null  object
#  6   latitude                        37434 non-null  float64
#  7   longitude                       37434 non-null  float64
#  8   room_type                       37434 non-null  object
#  9   price                           22308 non-null  float64
#  10  minimum_nights                  37434 non-null  int64
#  11  number_of_reviews               37434 non-null  int64
#  12  last_review                     25647 non-null  object
#  13  reviews_per_month               25647 non-null  float64
#  14  calculated_host_listings_count  37434 non-null  int64
#  15  availability_365                37434 non-null  int64
#  16  number_of_reviews_ltm           37434 non-null  int64
#  17  license                         5369 non-null   object
# dtypes: float64(4), int64(7), object(7)
# memory usage: 5.1+ MB

# %%
listing.isnull().sum()
# Out:
# id                                    0
# name                                  2
# host_id                               0
# host_name                            38
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             15126
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       11787
# reviews_per_month                 11787
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           32065
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
listing.head().T
# Out:
#                                                               0  \
# id                                                         2595
# name                            Skylit Midtown Castle Sanctuary
# host_id                                                    2845
# host_name                                              Jennifer
# neighbourhood_group                                   Manhattan
# neighbourhood                                           Midtown
# latitude                                               40.75356
# longitude                                             -73.98559
# room_type                                       Entire home/apt
# price                                                       NaN
# minimum_nights                                               30
# number_of_reviews                                            49
# last_review                                          2022-06-21
# reviews_per_month                                          0.26
# calculated_host_listings_count                                3
# availability_365                                            365
# number_of_reviews_ltm                                         0
# license                                                     NaN
#
#                                                                1  \
# id                                                          6848
# name                            Only 2 stops to Manhattan studio
# host_id                                                    15991
# host_name                                          Allen & Irina
# neighbourhood_group                                     Brooklyn
# neighbourhood                                       Williamsburg
# latitude                                                40.70935
# longitude                                              -73.95342
# room_type                                        Entire home/apt
# price                                                       96.0
# minimum_nights                                                30
# number_of_reviews                                            194
# last_review                                           2024-10-05
# reviews_per_month                                           1.01
# calculated_host_listings_count                                 1
# availability_365                                             173
# number_of_reviews_ltm                                          3
# license                                                      NaN
#
#                                                                                 2  \
# id                                                                           6872
# name                            Uptown Sanctuary w/ Private Bath (Month to Month)
# host_id                                                                     16104
# host_name                                                               Kahshanna
# neighbourhood_group                                                     Manhattan
# neighbourhood                                                         East Harlem
# latitude                                                                 40.80107
# longitude                                                               -73.94255
# room_type                                                            Private room
# price                                                                        59.0
# minimum_nights                                                                 30
# number_of_reviews                                                               1
# last_review                                                            2022-06-05
# reviews_per_month                                                            0.03
# calculated_host_listings_count                                                  2
# availability_365                                                               83
# number_of_reviews_ltm                                                           0
# license                                                                       NaN
#
#                                                       3  \
# id                                                 6990
# name                            UES Beautiful Blue Room
# host_id                                           16800
# host_name                                           Cyn
# neighbourhood_group                           Manhattan
# neighbourhood                               East Harlem
# latitude                                       40.78778
# longitude                                     -73.94759
# room_type                                  Private room
# price                                              67.0
# minimum_nights                                       30
# number_of_reviews                                   251
# last_review                                  2024-12-01
# reviews_per_month                                  1.34
# calculated_host_listings_count                        1
# availability_365                                    264
# number_of_reviews_ltm                                 5
# license                                             NaN
#
#                                                                                 4
# id                                                                           7064
# name                            Amazing location! Wburg. Large, bright & tranquil
# host_id                                                                     17297
# host_name                                                                  Joelle
# neighbourhood_group                                                      Brooklyn
# neighbourhood                                                        Williamsburg
# latitude                                                                 40.71248
# longitude                                                               -73.95881
# room_type                                                            Private room
# price                                                                         NaN
# minimum_nights                                                                 30
# number_of_reviews                                                              13
# last_review                                                            2022-09-12
# reviews_per_month                                                            0.07
# calculated_host_listings_count                                                  2
# availability_365                                                                0
# number_of_reviews_ltm                                                           0
# license                                                                       NaN

# %%
# Renaming Columns
listing.rename(
    columns={
        "number_of_reviews": "total_reviews",
        "calculated_host_listings_count": "host_listings_count",
    },
    inplace=True
)

# %%
# Checking for duplicates
listing.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Handling missing values
missing_values_perc = listing.isnull().mean() * 100
missing_values_perc[missing_values_perc > 0].sort_values(ascending=False)
# Out:
# license              85.657424
# price                40.407117
# last_review          31.487418
# reviews_per_month    31.487418
# host_name             0.101512
# name                  0.005343
# dtype: float64

# %%
# Imputing missing values
# For 'host_name', we can fill with 'Unknown' & 'name' with 'no_name'

import warnings
warnings.filterwarnings("ignore")

listing['host_name'].fillna('Unknown', inplace=True)
listing['name'].fillna('no_name', inplace=True)

# %%
# For 'reviews_per_month', we can fill with '0'
listing['reviews_per_month'].fillna(0, inplace=True)

# %%
# Dropping missing values in the target column 'price'
listing.dropna(subset=['price'], inplace=True)

# %%
listing.shape
# Out:
# (22308, 18)

# %%
# Creating a new column 'has_license'
listing['has_license'] = listing['license'].apply(lambda x: 1 if pd.notnull(x) else 0)

# dropping the 'license' column as it is no longer needed
listing.drop(columns=['license'], inplace=True)

# %%
# Creating a binary indicators for last_review
listing['last_review'] = pd.to_datetime(listing['last_review'], errors='coerce')
listing['last_review_num'] = listing['last_review'].apply(
    lambda x: 1 if pd.notnull(x) else 0
)   
# Dropping the 'last_review' column as it is no longer needed
listing.drop(columns=['last_review'], inplace=True)

# %%
# Replace null values in 'last_review' with 'No Review'

listing['last_review_num'].fillna('No Review', inplace=True)

# %%
listing.head()
# Out:
#      id                                               name  host_id  \
# 1  6848                   Only 2 stops to Manhattan studio    15991
# 2  6872  Uptown Sanctuary w/ Private Bath (Month to Month)    16104
# 3  6990                            UES Beautiful Blue Room    16800
# 5  7097      Perfect for Your Parents, With Garden & Patio    17571
# 6  7801                 Sunny Williamsburg Loft with Sauna    21207
#
#        host_name neighbourhood_group neighbourhood   latitude  longitude  \
# 1  Allen & Irina            Brooklyn  Williamsburg  40.709350 -73.953420
# 2      Kahshanna           Manhattan   East Harlem  40.801070 -73.942550
# 3            Cyn           Manhattan   East Harlem  40.787780 -73.947590
# 5           Jane            Brooklyn   Fort Greene  40.691940 -73.973890
# 6          Chaya            Brooklyn  Williamsburg  40.718807 -73.956177
#
#          room_type  price  minimum_nights  total_reviews  reviews_per_month  \
# 1  Entire home/apt   96.0              30            194               1.01
# 2     Private room   59.0              30              1               0.03
# 3     Private room   67.0              30            251               1.34
# 5     Private room  195.0               2            398               2.16
# 6  Entire home/apt  290.0              30             13               0.07
#
#    host_listings_count  availability_365  number_of_reviews_ltm  has_license  \
# 1                    1               173                      3            0
# 2                    2                83                      0            0
# 3                    1               264                      5            0
# 5                    2               190                     36            1
# 6                    1                 0                      1            0
#
#    last_review_num
# 1                1
# 2                1
# 3                1
# 5                1
# 6                1

# %%
# checking for categories in columns
listing['last_review_num'].value_counts()
# Out:
# last_review_num
# 1    15510
# 0     6798
# Name: count, dtype: int64

# %%
# dropping unnecessary columns
listing.drop(columns=['id', 'host_id', 'last_review_num'], inplace=True)

# %%
listing['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    12664
# Private room        9186
# Hotel room           372
# Shared room           86
# Name: count, dtype: int64

# %%
listing['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        10205
# Brooklyn          7455
# Queens            3420
# Bronx              912
# Staten Island      316
# Name: count, dtype: int64

# %%
categorical_columns = [
    'neighbourhood_group',
    'neighbourhood',
    'room_type']
# Converting categorical columns to 'category' dtype
for col in categorical_columns:
    listing[col] = listing[col].astype('category')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
listing.head()
# Out:
#                                                 name      host_name  \
# 1                   Only 2 stops to Manhattan studio  Allen & Irina
# 2  Uptown Sanctuary w/ Private Bath (Month to Month)      Kahshanna
# 3                            UES Beautiful Blue Room            Cyn
# 5      Perfect for Your Parents, With Garden & Patio           Jane
# 6                 Sunny Williamsburg Loft with Sauna          Chaya
#
#   neighbourhood_group neighbourhood   latitude  longitude        room_type  \
# 1            Brooklyn  Williamsburg  40.709350 -73.953420  Entire home/apt
# 2           Manhattan   East Harlem  40.801070 -73.942550     Private room
# 3           Manhattan   East Harlem  40.787780 -73.947590     Private room
# 5            Brooklyn   Fort Greene  40.691940 -73.973890     Private room
# 6            Brooklyn  Williamsburg  40.718807 -73.956177  Entire home/apt
#
#    price  minimum_nights  total_reviews  reviews_per_month  \
# 1   96.0              30            194               1.01
# 2   59.0              30              1               0.03
# 3   67.0              30            251               1.34
# 5  195.0               2            398               2.16
# 6  290.0              30             13               0.07
#
#    host_listings_count  availability_365  number_of_reviews_ltm  has_license
# 1                    1               173                      3            0
# 2                    2                83                      0            0
# 3                    1               264                      5            0
# 5                    2               190                     36            1
# 6                    1                 0                      1            0

# %%
import plotly.express as px
df_grouped = listing.groupby('neighbourhood_group', as_index=False)['price'].mean()

fig = px.bar(
    df_grouped,
    x='neighbourhood_group',
    y='price',
    color='neighbourhood_group',
    title='Average Price by Neighbourhood Group',
    labels={'price': 'Average Price ($)', 'neighbourhood_group': 'Neighbourhood Group'}
)
fig.update_layout(
    xaxis_title='Neighbourhood Group',
    yaxis_title='Average Price ($)',
    template='plotly_white'
)
fig.show()

# %% [markdown]
# From the plot we can conclude that Manhattan is the most expensive neighboorhood and Bronx the least expensive among them

# %%
# Distribution by 'room_type'
df_room_type = listing.groupby('room_type', as_index=False)['price'].mean()

fig = px.bar(
    df_room_type,
    x='room_type',
    y='price',
    color='room_type',
    title='Average Price by Room Type',
    labels={'price': 'Average Price ($)', 'room_type': 'Room Type'}
)
fig.update_layout(
    xaxis_title='Room Type',
    yaxis_title='Average Price ($)',
    template='plotly_white'
)
fig.show()

# %% [markdown]
# Hotel prices are the most expensive and shared rooms are the least expensive.

# %%
# price vs license

import plotly.express as px
df_license = listing.groupby('has_license', as_index=False)['price'].mean()
fig = px.bar(
    df_license,
    x='has_license',
    y='price',
    color='has_license',
    title='Average Price by License Status',
    labels={'price': 'Average Price ($)', 'has_license': 'Has License'}
)
fig.update_layout(
    xaxis_title='Has License',
    yaxis_title='Average Price ($)',
    template='plotly_white'
)
fig.show()

# %% [markdown]
# Houses with licences tend to avarege a higher price than houses without licences

# %%
fig = px.box(
    listing,
    x='neighbourhood_group',
    y='price',
    color='neighbourhood_group',
    title='Price Distribution by Neighbourhood Group',
    labels={'price': 'Price ($)', 'neighbourhood_group': 'Neighbourhood Group'}
)
fig.update_layout(
    xaxis_title='Neighbourhood Group',
    yaxis_title='Price ($)',
    template='plotly_white'
)
fig.show()

# %%
listing1 = listing.copy()

# %%
import pandas as pd
import plotly.express as px

# Step 1: Create estimated 'booked_days' column
listing1['booked_days'] = 365 - listing['availability_365']

# Step 2: Average booked days per room type
df_bookings = listing1.groupby('room_type', as_index=False)['booked_days'].mean()

# Step 3: Plot
fig = px.bar(
    df_bookings,
    x='room_type',
    y='booked_days',
    color='room_type',
    title='Average Booked Days by Room Type (Estimated)',
    labels={
        'room_type': 'Room Type',
        'booked_days': 'Estimated Booked Days'
    }
)

fig.update_layout(
    xaxis_title='Room Type',
    yaxis_title='Avg. Booked Days (per Year)',
    template='plotly_white'
)

fig.show()

# %% [markdown]
# Majority of the people booked private rooms, and hotel rooms were the least booked, this could be as a hotel rooms being the most expensive rooms

# %%
import plotly.express as px

# Group by neighbourhood and calculate average total reviews
grouped_review = listing1.groupby('neighbourhood_group', as_index=False)['total_reviews'].mean()

# Sort neighbourhoods by review count for better ordering in the plot
grouped_review = grouped_review.sort_values(by='total_reviews', ascending=True)

# Create horizontal bar chart
fig = px.bar(
    grouped_review,
    x='total_reviews',
    y='neighbourhood_group',
    orientation='h',
    title='📊 Average Total Reviews by Neighbourhood',
    color='total_reviews',
    color_continuous_scale='viridis',
    labels={'total_reviews': 'Average Total Reviews', 'neighbourhood': 'Neighbourhood'}
)

# Update layout for better spacing and readability
fig.update_layout(
    template='plotly_white',
    xaxis_title='Average Total Reviews',
    yaxis_title='Neighbourhood',
    title_x=0.5,
    margin=dict(l=100, r=30, t=80, b=40),
    height=600
)

fig.show()

# %% [markdown]
# Queens received the highest number of reviews, while Manhattan received the least number of reviews, Queens was the second least expensive neighboor hood, which made it prefferable for the people

# %%
listing.head()
# Out:
#                                                 name      host_name  \
# 1                   Only 2 stops to Manhattan studio  Allen & Irina
# 2  Uptown Sanctuary w/ Private Bath (Month to Month)      Kahshanna
# 3                            UES Beautiful Blue Room            Cyn
# 5      Perfect for Your Parents, With Garden & Patio           Jane
# 6                 Sunny Williamsburg Loft with Sauna          Chaya
#
#   neighbourhood_group neighbourhood   latitude  longitude        room_type  \
# 1            Brooklyn  Williamsburg  40.709350 -73.953420  Entire home/apt
# 2           Manhattan   East Harlem  40.801070 -73.942550     Private room
# 3           Manhattan   East Harlem  40.787780 -73.947590     Private room
# 5            Brooklyn   Fort Greene  40.691940 -73.973890     Private room
# 6            Brooklyn  Williamsburg  40.718807 -73.956177  Entire home/apt
#
#    price  minimum_nights  total_reviews  reviews_per_month  \
# 1   96.0              30            194               1.01
# 2   59.0              30              1               0.03
# 3   67.0              30            251               1.34
# 5  195.0               2            398               2.16
# 6  290.0              30             13               0.07
#
#    host_listings_count  availability_365  number_of_reviews_ltm  has_license
# 1                    1               173                      3            0
# 2                    2                83                      0            0
# 3                    1               264                      5            0
# 5                    2               190                     36            1
# 6                    1                 0                      1            0
